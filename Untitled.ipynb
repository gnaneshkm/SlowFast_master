# %%
import pandas as pd 
df=pd.read_csv("/home/gnanesh/Downloads/train.csv",sep=' ')

# %%
df1=df[0:20]
df1.tail()
# Out:
#    original_video_id  video_id  frame_id  \
# 15   theodore_stereo         0        15
# 16   theodore_stereo         0        16
# 17   theodore_stereo         0        17
# 18   theodore_stereo         0        18
# 19   theodore_stereo         0        19
#
#                                                  path labels
# 15  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 16  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 17  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 18  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 19  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""

# %%
df1.to_csv("/home/gnanesh/train_sam.csv",index=False,sep=' ')

# %%
import pandas as pd 
df=pd.read_csv("/home/gnanesh/Downloads/train_bbox2 .csv")

# %%
df.head()
# Out:
#    images  0  0.5171875  0.73515625  0.59921875  0.91796875  1   4
# 0  images  0   0.557813    0.074219    0.633594    0.236719  1  16
# 1  images  0   0.689844    0.133594    0.778906    0.255469  1  17
# 2  images  1   0.080469    0.325781    0.264844    0.445312  1   4
# 3  images  1   0.314844    0.052344    0.383594    0.160156  1  16
# 4  images  1   0.385937    0.028125    0.450000    0.121094  1  17

# %%
df2=df.loc[df['0']<=3]
df2.tail()
# Out:
#    images  0  0.5171875  0.73515625  0.59921875  0.91796875  1   4
# 5  images  2   0.059375    0.283594    0.193750    0.361719  1   4
# 6  images  2   0.182812    0.121094    0.253125    0.217188  1  16
# 7  images  3   0.368750    0.612500    0.603125    0.970313  1   4
# 8  images  3   0.185156    0.101562    0.436719    0.489844  1  16
# 9  images  3   0.431250    0.007031    0.515625    0.164062  1  17

# %%
df2.to_csv("/home/gnanesh/train_box2.csv",index=False)

# %%
val=df.loc[df["0"].between(4,7)]
val.tail()
# Out:
#     images  0  0.5171875  0.73515625  0.59921875  0.91796875  1     4
# 12  images  5   0.356250    0.782031    0.464062    0.985156  1    16
# 13  images  6   0.087500    0.671094    0.256250    0.806250  1  1948
# 14  images  7   0.716406    0.654687    0.900000    0.807031  1     4
# 15  images  7   0.285156    0.689844    0.389844    0.884375  2    16
# 16  images  7   0.482031    0.059375    0.775000    0.453906  1    17

# %%
val_d=val.rename(columns=val.iloc[0]).drop(val.index[0])
val_d.head()
# Out:
#     images  4  0.74765625  0.52109375  0.91171875  0.540625  1  1948
# 11  images  5    0.300000    0.868750    0.359375  0.964063  1  1948
# 12  images  5    0.356250    0.782031    0.464062  0.985156  1    16
# 13  images  6    0.087500    0.671094    0.256250  0.806250  1  1948
# 14  images  7    0.716406    0.654687    0.900000  0.807031  1     4
# 15  images  7    0.285156    0.689844    0.389844  0.884375  2    16

# %%
val_d.reset_index()
# Out:
#    index  images  4  0.74765625  0.52109375  0.91171875  0.540625  1  1948
# 0     11  images  5    0.300000    0.868750    0.359375  0.964063  1  1948
# 1     12  images  5    0.356250    0.782031    0.464062  0.985156  1    16
# 2     13  images  6    0.087500    0.671094    0.256250  0.806250  1  1948
# 3     14  images  7    0.716406    0.654687    0.900000  0.807031  1     4
# 4     15  images  7    0.285156    0.689844    0.389844  0.884375  2    16
# 5     16  images  7    0.482031    0.059375    0.775000  0.453906  1    17

# %%
val_d=val_d.reset_index()

# %%
val_d.head()
# Out:
#    index  images  4  0.74765625  0.52109375  0.91171875  0.540625  1  1948
# 0     11  images  5    0.300000    0.868750    0.359375  0.964063  1  1948
# 1     12  images  5    0.356250    0.782031    0.464062  0.985156  1    16
# 2     13  images  6    0.087500    0.671094    0.256250  0.806250  1  1948
# 3     14  images  7    0.716406    0.654687    0.900000  0.807031  1     4
# 4     15  images  7    0.285156    0.689844    0.389844  0.884375  2    16

# %%
val_d=val_d.drop(['index'],axis=1)

# %%
val_d.head()
# Out:
#    images  4  0.74765625  0.52109375  0.91171875  0.540625  1  1948
# 0  images  5    0.300000    0.868750    0.359375  0.964063  1  1948
# 1  images  5    0.356250    0.782031    0.464062  0.985156  1    16
# 2  images  6    0.087500    0.671094    0.256250  0.806250  1  1948
# 3  images  7    0.716406    0.654687    0.900000  0.807031  1     4
# 4  images  7    0.285156    0.689844    0.389844  0.884375  2    16

# %%
val_d.to_csv("/home/gnanesh/val_box2.csv",index=False)

# %%
import pandas as pd 
df=pd.read_csv("/home/gnanesh/Downloads/train.csv",sep=' ')
df.head()
# Out:
#   original_video_id  video_id  frame_id  \
# 0   theodore_stereo         0         0
# 1   theodore_stereo         0         1
# 2   theodore_stereo         0         2
# 3   theodore_stereo         0         3
# 4   theodore_stereo         0         4
#
#                                                 path labels
# 0  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 1  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 2  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 3  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 4  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""

# %%
df2=df[20:40]
df2.tail()
# Out:
#    original_video_id  video_id  frame_id  \
# 35   theodore_stereo         0        35
# 36   theodore_stereo         0        36
# 37   theodore_stereo         0        37
# 38   theodore_stereo         0        38
# 39   theodore_stereo         0        39
#
#                                                  path labels
# 35  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 36  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 37  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 38  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 39  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""

# %%
df2=df2.reset_index()

# %%
df2.head()
# Out:
#    index original_video_id  video_id  frame_id  \
# 0     20   theodore_stereo         0        20
# 1     21   theodore_stereo         0        21
# 2     22   theodore_stereo         0        22
# 3     23   theodore_stereo         0        23
# 4     24   theodore_stereo         0        24
#
#                                                 path labels
# 0  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 1  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 2  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 3  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 4  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""

# %%
df2=df2.drop(['index'],axis=1)

# %%
df2.head()
# Out:
#   original_video_id  video_id  frame_id  \
# 0   theodore_stereo         0        20
# 1   theodore_stereo         0        21
# 2   theodore_stereo         0        22
# 3   theodore_stereo         0        23
# 4   theodore_stereo         0        24
#
#                                                 path labels
# 0  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 1  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 2  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 3  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 4  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""

# %%
df2.frame_id=df2.frame_id+20
df2.head()
# Out:
#   original_video_id  video_id  frame_id  \
# 0   theodore_stereo         0         0
# 1   theodore_stereo         0         1
# 2   theodore_stereo         0         2
# 3   theodore_stereo         0         3
# 4   theodore_stereo         0         4
#
#                                                 path labels
# 0  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 1  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 2  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 3  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""
# 4  /mnt/dst_datasets/own_omni_dataset/theodore_v3...     ""

# %%
df2.to_csv("/home/gnanesh/val_path.csv",sep=' ',index=False)

# %%
val_b=pd.read_csv("/home/gnanesh/val_box.csv")
val_b.head()
# Out:
#    images  4  0.6515625  0.86015625  0.71484375  0.9546875  1   4.1
# 0  images  4   0.498437    0.871094    0.564063   0.992188  1    16
# 1  images  4   0.659375    0.700781    0.842969   0.885938  1    17
# 2  images  5   0.229687    0.853906    0.283594   0.920312  1  1948
# 3  images  5   0.202344    0.753906    0.328906   0.914062  1    16
# 4  images  6   0.042969    0.575781    0.277344   0.740625  1  1948

# %%
val_b['4']=val_b['4']-4
val_b.head()
# Out:
#    images  4  0.6515625  0.86015625  0.71484375  0.9546875  1   4.1
# 0  images  0   0.498437    0.871094    0.564063   0.992188  1    16
# 1  images  0   0.659375    0.700781    0.842969   0.885938  1    17
# 2  images  1   0.229687    0.853906    0.283594   0.920312  1  1948
# 3  images  1   0.202344    0.753906    0.328906   0.914062  1    16
# 4  images  2   0.042969    0.575781    0.277344   0.740625  1  1948

# %%
val_b=val_b.rename(columns={"4": "0", "4.1": "4"})

# %%
val_b.head()
# Out:
#    images  0  0.6515625  0.86015625  0.71484375  0.9546875  1     4
# 0  images  0   0.498437    0.871094    0.564063   0.992188  1    16
# 1  images  0   0.659375    0.700781    0.842969   0.885938  1    17
# 2  images  1   0.229687    0.853906    0.283594   0.920312  1  1948
# 3  images  1   0.202344    0.753906    0.328906   0.914062  1    16
# 4  images  2   0.042969    0.575781    0.277344   0.740625  1  1948

# %%
val_b.to_csv("/home/gnanesh/val_box1.csv",index=False)

# %%
# Out:
#    images  4  0.6515625  0.86015625  0.71484375  0.9546875  1   4.1
# 0  images  0   0.498437    0.871094    0.564063   0.992188  1    16
# 1  images  0   0.659375    0.700781    0.842969   0.885938  1    17
# 2  images  1   0.229687    0.853906    0.283594   0.920312  1  1948
# 3  images  1   0.202344    0.753906    0.328906   0.914062  1    16
# 4  images  2   0.042969    0.575781    0.277344   0.740625  1  1948
